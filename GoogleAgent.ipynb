# %%
import os
from getpass import getpass

try:
    # Prompt user to enter the API key securely
    GOOGLE_API_KEY = getpass("🔐 Enter your Gemini API key: ")

    if not GOOGLE_API_KEY:
        raise ValueError("No API key provided.")

    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")

except Exception as e:
    print(f"🔑 Authentication Error: {e}")
# Out:
# 🔐 Enter your Gemini API key: ··········
# ✅ Gemini API key setup complete.

# %%
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# /usr/local/lib/python3.12/dist-packages/google/cloud/aiplatform/models.py:52: FutureWarning: Support for google-cloud-storage < 3.0.0 will be removed in a future version of google-cloud-aiplatform. Please upgrade to google-cloud-storage >= 3.0.0.
#   from google.cloud.aiplatform.utils import gcs_utils
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %% [markdown]
# `Prompt -> LLM -> Text`
#
# An AI Agent takes this one step further. An agent can think, take actions, and observe the results of those actions to give you a better answer.
#
# `Prompt -> Agent -> Thought -> Action -> Observation -> Final Answer`
#
# In this notebook, we'll build an agent that can take the action of searching Google. Let's see the difference!

# %%
root_agent = Agent(
    name="helpful_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
    tools=[google_search],
)

print("✅ Root Agent defined.")
# Out:
# ✅ Root Agent defined.

# %%
runner = InMemoryRunner(agent=root_agent)

print("✅ Runner created.")
# Out:
# ✅ Runner created.

# %%
response = await runner.run_debug("What's the AQI in pune?")
# Out:
#  ### Continue session: debug_session_id
#
# User > What's the AQI in pune?
# helpful_assistant > The Air Quality Index (AQI) in Pune varies depending on the source and the exact time of measurement. As of the latest available information, Pune's AQI has been reported in the following ranges:
#
# *   **155 (Unhealthy)** with PM2.5 at 61µg/m³ and PM10 at 78µg/m³.
# *   **165 (Poor)**, which is 21 points higher than the previous day. This level indicates that those with heart or lung conditions should avoid outdoor exposure. PM2.5 and PM10 are measured at 64 µg/m³ and 84 µg/m³ respectively. Ozone concentration is at 23 ppb and NO2 is at 16 ppb.
# *   **235 (Severe)**, last updated on November 19, 2025, at 03:47:51 AM local time. The major pollutants are PM2.5 at 158µg/m³ and PM10 at 198µg/m³.
# *   **321 (Hazardous)**, with PM10 at 167.8, PM25 at 163.73.
#
# It's important to note that AQI levels can fluctuate throughout the day. For sensitive groups like children or individuals with respiratory issues, it's advisable to limit outdoor activities when the AQI is in the "Poor" or higher categories.
